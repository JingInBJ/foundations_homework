# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# !pip install python-dotenv
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !touch .env

# %%
import os

API_KEY = os.getenv("DARKSKY_API_KEY")
# not sure why the API_KEY cannot be defined here

API_KEY= '2a01789f9dd28b5b9a6d65e8d1974795'

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
# I found a big area in China will be defined as Shanghai timezone, although I typed in coordinates of Beijing and other cities.
latitute = '59.5619'
longtitute = '30.1850'
url = 'https://api.darksky.net/forecast/' + API_KEY + "/" + latitute + "," + longtitute
response = requests.get(url)
location = response.json()

# %%
location
# Out:
# {'latitude': 59.5619,
#  'longitude': 30.185,
#  'timezone': 'Europe/Moscow',
#  'currently': {'time': 1560221244,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 57.42,
#   'apparentTemperature': 57.42,
#   'dewPoint': 46.49,
#   'humidity': 0.67,
#   'pressure': 1022.83,
#   'windSpeed': 7.9,
#   'windGust': 12.91,
#   'windBearing': 246,
#   'cloudCover': 0.66,
#   'uvIndex': 0,
#   'visibility': 6.22,
#   'ozone': 330.95},
#  'hourly': {'summary': 'Light rain starting tonight, continuing until tomorrow morning.',
#   'icon': 'rain',
#   'data': [{'time': 1560218400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56.73,
#     'apparentTemperature': 56.73,
#     'dewPoint': 45.96,
#     'humidity': 0.67,
#     'pressure': 1022.71,
#     'windSpeed': 7.6,
#     'windGust': 11.84,
# ...

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
location.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'hourly', 'daily', 'flags', 'offset'])

# %%
location['currently']
#it's a dict
# Out:
# {'time': 1560221244,
#  'summary': 'Mostly Cloudy',
#  'icon': 'partly-cloudy-day',
#  'precipIntensity': 0,
#  'precipProbability': 0,
#  'temperature': 57.42,
#  'apparentTemperature': 57.42,
#  'dewPoint': 46.49,
#  'humidity': 0.67,
#  'pressure': 1022.83,
#  'windSpeed': 7.9,
#  'windGust': 12.91,
#  'windBearing': 246,
#  'cloudCover': 0.66,
#  'uvIndex': 0,
#  'visibility': 6.22,
#  'ozone': 330.95}

# %%
print("The current windspeed in the city is", location['currently']['windSpeed'])
# Out:
# The current windspeed in the city is 7.9

# %%
print("It feels", location['currently']['apparentTemperature'] - location['currently']['temperature'], "°F warmer.")
# Out:
# It feels 0.0 °F warmer.

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
location['daily']
# Out:
# {'summary': 'Light rain tomorrow and Friday, with high temperatures rising to 79°F on Monday.',
#  'icon': 'rain',
#  'data': [{'time': 1560200400,
#    'summary': 'Mostly cloudy starting in the evening.',
#    'icon': 'partly-cloudy-night',
#    'sunriseTime': 1560213828,
#    'sunsetTime': 1560280608,
#    'moonPhase': 0.29,
#    'precipIntensity': 0.0001,
#    'precipIntensityMax': 0.0017,
#    'precipIntensityMaxTime': 1560283200,
#    'precipProbability': 0.05,
#    'precipType': 'rain',
#    'temperatureHigh': 71.48,
#    'temperatureHighTime': 1560254400,
#    'temperatureLow': 50.78,
#    'temperatureLowTime': 1560315600,
#    'apparentTemperatureHigh': 71.48,
#    'apparentTemperatureHighTime': 1560254400,
#    'apparentTemperatureLow': 50.78,
#    'apparentTemperatureLowTime': 1560315600,
#    'dewPoint': 44.14,
#    'humidity': 0.5,
#    'pressure': 1022.74,
#    'windSpeed': 3.97,
#    'windGust': 13.19,
#    'windGustTime': 1560222000,
#    'windBearing': 292,
# ...

# %%
forecast = location['daily']['data'][0]
print("The visibility of the noon is", forecast['moonPhase'])
#assume the first one is the most current one
# Out:
# The visibility of the noon is 0.29

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
print("The difference between the high and low temperatures for today is ", round(forecast['temperatureHigh'] - forecast['temperatureLow']), "°F.")
# Out:
# The difference between the high and low temperatures for today is  21 °F.

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
forecasts = location['daily']['data']
type(forecasts)
# Out:
# list

# %%
forecast
# Out:
# {'time': 1560805200,
#  'summary': 'Partly cloudy starting in the evening.',
#  'icon': 'partly-cloudy-day',
#  'sunriseTime': 1560818466,
#  'sunsetTime': 1560885737,
#  'moonPhase': 0.54,
#  'precipIntensity': 0.0014,
#  'precipIntensityMax': 0.0182,
#  'precipIntensityMaxTime': 1560805200,
#  'precipProbability': 0.18,
#  'precipType': 'rain',
#  'temperatureHigh': 69.93,
#  'temperatureHighTime': 1560855600,
#  'temperatureLow': 53.38,
#  'temperatureLowTime': 1560902400,
#  'apparentTemperatureHigh': 69.93,
#  'apparentTemperatureHighTime': 1560855600,
#  'apparentTemperatureLow': 53.38,
#  'apparentTemperatureLowTime': 1560902400,
#  'dewPoint': 46.07,
#  'humidity': 0.56,
#  'pressure': 1010.68,
#  'windSpeed': 9.28,
#  'windGust': 28.32,
#  'windGustTime': 1560888000,
#  'windBearing': 290,
#  'cloudCover': 0.33,
#  'uvIndex': 7,
#  'uvIndexTime': 1560852000,
#  'visibility': 9.44,
#  'ozone': 324.25,
#  'temperatureMin': 55.07,
#  'temperatureMinTime': 1560823200,
# ...

# %%
for forecast in forecasts: 
    if forecast['temperatureHigh'] > 84:
        print("The high temperature is " + str(forecast['temperatureHigh']) + "°F. It is hot." )
    elif forecast['temperatureHigh'] > 68:
        print("The high temperature is " + str(forecast['temperatureHigh']) + "°F. It is warm." )
    else:
        print("The high temperature is " + str(forecast['temperatureHigh']) + "°F. It is cold." )
# Out:
# The high temperature is 71.48°F. It is warm.
# The high temperature is 61.82°F. It is cold.
# The high temperature is 71.09°F. It is warm.
# The high temperature is 70.84°F. It is warm.
# The high temperature is 70.68°F. It is warm.
# The high temperature is 78.43°F. It is warm.
# The high temperature is 78.8°F. It is warm.
# The high temperature is 69.93°F. It is warm.

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
forecasts = location['daily']['data']
High_temp = []
for forecast in forecasts:
    High_temp.append(forecast['temperatureHigh'])
print(High_temp)

if forecast['temperatureHigh'] == max(High_temp):
    print(forecast['time'])
# Out:
# [71.48, 61.82, 71.09, 70.84, 70.68, 78.43, 78.8, 69.93]

# %%
from datetime import datetime
time = int(forecast['time'])
print("The hottest day next week will be " + datetime.utcfromtimestamp(time).strftime('%Y-%m-%d') +  ". The high temperature that day will be", max(High_temp),"°F.")
# Out:
# The hottest day next week will be 2019-06-17. The high temperature that day will be 78.8 °F.

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
latitute = '25.7617'
longtitute = '-80.1918'

# %%
url = 'https://api.darksky.net/forecast/' + API_KEY + "/" + latitute + "," + longtitute
response = requests.get(url)

# %%
Miami_loc = response.json()

# %%
Miami_loc
#I checked the coordinates from Google but the timezone below shows 'New_York'
# Out:
# {'latitude': 25.7617,
#  'longitude': -80.1918,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1560223695,
#   'summary': 'Humid',
#   'icon': 'clear-night',
#   'nearestStormDistance': 38,
#   'nearestStormBearing': 333,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 80.11,
#   'apparentTemperature': 84.49,
#   'dewPoint': 73.43,
#   'humidity': 0.8,
#   'pressure': 1017.65,
#   'windSpeed': 1.51,
#   'windGust': 3.96,
#   'windBearing': 188,
#   'cloudCover': 0.09,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 288.45},
#  'minutely': {'summary': 'Humid for the hour.',
#   'icon': 'clear-night',
#   'data': [{'time': 1560223680, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560223740, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560223800, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560223860, 'precipIntensity': 0, 'precipProbability': 0},
# ...

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
forecasts_hour = Miami_loc['hourly']['data']
count_85 = 0
for forecast in forecasts_hour:
    if forecast['temperature'] > 85:
        count_85 = count_85 + 1
print(count_85)
# Out:
# 22

# %%
ratio = print(round(100 * count_85 / len(forecasts_hour)),"%")
# Out:
# 45 %

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*
